# %%
#W8A
class Point3:
    def translate(self, dx, dy, dz):
        self.x += dx
        self.y += dy
        self.z += dz
p = Point3(1, 2, 3)   
p.translate(1, 1, 1)
print(p)
# Out:
# 1

# %%
#W8A1
class Cylinder:
    def __init__(self, radius, h):
        self.radius = radius
        self.h = h
    def dien_tich_toan_phan(self):
        return 2 * 3.14 * self.radius * (self.radius + self.h)
    def the_tich(self):
        return 3.14 * self.radius * self.radius * self.h
radius, h =list(map(float,input().split()))
cylinder = Cylinder(radius, h)
print(f"{cylinder.dien_tich_toan_phan():.2f}")
print(f"{cylinder.the_tich():.2f}")
# Out:
# 18.84
# 6.28

# %%
#W8A2
class Date:
    def __init__(self, dd, mm, yyyy):
        self.dd = dd
        self.mm = mm
        self.yyyy = yyyy        
    def date(self):
        c=0
        if yyyy%400==0 or (yyyy%4==0 and yyyy%100!=0):
            c=1 
        a=[1, 3, 5, 7, 8, 10, 12]
        b=[4, 6, 9, 11]
        if (mm in a and 1<=dd<=30) or (mm in b and 1<=dd<=29):
            return f"{dd+1}/{mm}/{yyyy}"
        if (mm in b and dd==30) or (mm in a and dd==31 and mm!=12):
            return f"1/{mm+1}/{yyyy}"
        if mm==12 and dd==31:
            return f"1/1/{yyyy+1}"
        if (c==1 and dd<=28 and mm==2) or (c==0 and dd<=27 and mm==2):
            return f"{dd+1}/{mm}/{yyyy}"
        if (c==1 and dd==29 and mm==2) or (c==0 and dd==28 and mm==2):
            return f"1/{mm+1}/{yyyy}"
        else:
            return "INVALID"
dd, mm, yyyy= map(int, input().split("/"))
dates = Date(dd, mm, yyyy) 
print(dates.date())
# Out:
# INVALID

# %%
#W8A3
from math import sqrt
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def point(self):
        if self.x==0==self.y:
            return f"M là tọa độ gốc, khoảng cách là 0"
        if self.x!=0 and self.y==0:
            return f"M nằm trên trục hoành, khoảng cách tới O là {self.x:.2f}"
        if self.x==0 and self.y!=0:
            return f"M nằm trên trục tung, khoảng cách tới O là {self.y:.2f}"
        if self.x!=0 and self.y!=0:
            a = sqrt(self.x**2 +self.y**2)
            return f"M không là gốc tọa độ, không nằm trên trục tung, trục hoành, khoảng cách tới O là {a:.2f}"
x, y = map(float, input().split())
points=Point(x, y) 
print(points.point())
# Out:
# M không là gốc tọa độ, không nằm trên trục tung, trục hoành, khoảng cách tới O là 5.00

# %%
#W8A4
class Calculator:
    def __init__(self, a, b):
        self.a = a
        self.b = b
    def add(self):
        return self.a + self.b   
    def subtract(self):
        return self.a + self.b
    def product(self):
        return self.a * self.b
    def devide(self):
        if self.b!=0: 
            return self.a / self.b
        else:
            return "Lỗi"
    def power(self):
        return self.a ** self.b
    def mod(self):
        if self.b!=0:
            return self.a % self.b
        else:
            return "Lỗi" 
    def set_numbers(self):
        a,b=map(float, input().split())
        self.a = a
        self.b = b
a, b= map(float, input().split())
calculator = Calculator(a,b)
while True:
    print("Menu")
    print("1. Cộng")
    print("2. Trừ")   
    print("3. Nhân")
    print("4. Chia") 
    print("5. Mũ") 
    print("6. Chia lấy dư")      
    print("7. Thay số")  
    choice = input()
    if choice == "1":
        print(calculator.add())
    if choice == "2":
        print(calculator.subtract())
    if choice == "3":
        print(calculator.product())
    if choice == "4":
        print(calculator.devide())
    if choice == "5":
        print(calculator.power())
    if choice == "6":
        print(calculator.mod)
    if choice == "7":
        print(calculator.set_numbers())
    print("Bạn có muốn thoát?")
    ans = input()
    a=['Yes', 'yes', 'YES']
    if ans in a:
        break
# Out:
# Menu
# 1. Cộng
# 2. Trừ
# 3. Nhân
# 4. Chia
# 5. Mũ
# 6. Chia lấy dư
# 7. Thay số
# 3.0
# Bạn có muốn thoát?
# Menu
# 1. Cộng
# 2. Trừ
# 3. Nhân
# 4. Chia
# 5. Mũ
# 6. Chia lấy dư
# 7. Thay số
# 2.0
# Bạn có muốn thoát?

# %%
#W8A5
class ShoppingCart:
    def __init__(self, name, price):
        self.name = name
        self.price = price
    def add(self):
        return c.append(self.name) 
    def remove(self):
        return c.pop(self.name)
    def check(self):
        return len(c)
    def total(self):
        for i in range(len(a)):
            if a[i]["self.name"]== self.price:
                sum+= self.price
    def show(self):
        return c
    def remove_all(self):
        c=[]
import ast
a = ast.literal_eval(input())
# name = input()
# price = float(input())
# c=[]
# ShoppingCart = ShoppingCart(name, price)
while True:
    name = input()
    price = float(input())
    c=[]
    ShoppingCart = ShoppingCart(name, price)
    print("Menu")
    print("2. Thêm vào giỏ")   
    print("3. Xóa khỏi giỏ")
    print("4. Kiểm tra sô lượng") 
    print("5. Tính tiền")
    print("6. Hiện thị giỏ hàng")      
    print("7. Xóa toàn bộ")
    choice=int(input())
    if choice == 2:
        print(ShoppingCart.add())
    if choice == 3:
        print(ShoppingCart.remove())
    if choice == 4:
        print(ShoppingCart.check())
    if choice == 5:
        print(ShoppingCart.total())
    if choice == 6:
        print(ShoppingCart.show())
    if choice == 7:
        print(ShoppingCart.remove_all())
    print("Có muốn thoát không?")
    ans=input()
    if ans == "yes":
        break
# Out:
# Menu
# 2. Thêm vào giỏ
# 3. Xóa khỏi giỏ
# 4. Kiểm tra sô lượng
# 5. Tính tiền
# 6. Hiện thị giỏ hàng
# 7. Xóa toàn bộ
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 42
#      40     print(ShoppingCart.add())
#      41     name=input()
# ---> 42     price = float(input())
#      43 if choice == 3:
#      44     print(ShoppingCart.remove())
#
# ValueError: could not convert string to float: 'yes'

# %%
#W8A6
class Rectangle:
    def __init__(self, w, h):
        self.w = w
        self.h = h 
        self.k = k
    def area(self):
        return self.w * self.h
    def perimeter(self):
        return 2 * (self.w + self.h)
    def scale(self,k):
       
        # w = w*self.k
        self.h = self.h * k
        self.w = self.w * k
        # self.k = k
w, h, k= map(int,input().split())
Rectangle=Rectangle(w,h)
Rectangle.scale(k)
print(F"{Rectangle.area():.2f} {Rectangle.perimeter():.2f}")
# Out:
# 40.00 28.00

# %%
#W8A7
class Fraction:
    def __init__(self, num, den):
        self.num =num
        self.den = den
    def rutgon(self):    
        if self.num<=self.den:
            max=0
            for i in range (2,self.num+1):
                if self.num % i==0 and self.den%i==0:
                    if max<i:
                        max=i
            self.num/=max
            self.den/=max
        else:
            for i in range (2,self.den+1):
                if self.num % i==0 and self.den%i==0:
                    self.num/=i
                    self.den/=i            
        return f"{self.num:.0f}/{self.den:.0f}"            
    def add(self, other):
        self.num = other.num * self.den + other.den * self.num
        self.den = other.den * self.den              
        return Fraction.rutgon(self)
    def sub(self, other):
        self.num = - other.num * self.den + other.den * self.num
        self.den = other.den * self.den              
        return Fraction.rutgon(self)
    def div(self, other):
        self.num = other.den * self.num 
        self.den = other.num * self.den              
        return Fraction.rutgon(self)
    def mul(self, other):
        self.num = other.num * self.num 
        self.den = other.den * self.den              
        return Fraction.rutgon(self)
a, b, op, c, d= input().split()
a=int(a)
b=int(b)
c=int(c)
d=int(d)
fraction1 = Fraction(a, b) 
fraction2 = Fraction(c, d)
if op == "+":
    print (fraction1.add(fraction2))    
if op == "-":
    print(fraction1.sub(fraction2))
if op == "/":
    print(fraction1.div(fraction2))
if op == "*":
    print(fraction1.mul(fraction2))
# Out:
# 1/1

# %%
#W8A8
class BankAccount:
    def __init__(self,owner, balance):
        self.owner = balance
        self.balance = owner
    def deposit(self, k):
        self.owner= self.owner + k
        return self.owner
    def withdraw(self, k):
        self.owner=self.owner -k
        return self.owner
owner, balance= input().split()
balance=int(balance)
bankaccount = BankAccount(owner, balance)  
a= int(input("Nhập số lần: ")) 
for i in range(a):
    b= input("Yêu cầu: ")
    if 'DEPOSIT' in b:
        b=b.strip("DEPOSIT ")     
        b=int(b)
        bankaccount= bankaccount.deposit(b)
        # bankaccount=bankaccount(k, balance)
    else:
        b=b.strip("WITHDRAW ")     
        b=int(b)
        k = bankaccount.withdraw(b)    
        bankaccount=bankaccount(k, balance)
print(bankaccount)
# Out:
# 15

# %%
#W8A9

# %%
#W8A10

# %%
#W8A11

# %%
#W8A12

# %%
#W8A13

# %%
#W8A14

# %%
#W8A15
